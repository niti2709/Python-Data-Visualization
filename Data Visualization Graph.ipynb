# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import cufflinks as cf

# %%
df = pd.read_csv('https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
#id column has huge range due to which we are not able to visuallize other column

# %%
df = df.drop('Id',axis=1)

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
#df.plot() is representing all the column

# %%
df.plot(kind='bar',figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind='bar',figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa

# %%
df.iloc[[5]].plot(kind='barh',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind='barh',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#in between 0 to 1 range of values there are almost 50 data set available

# %%
df['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df['SepalLengthCm'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# x-axis: range
# y-axis : frequency

# %%
df['SepalLengthCm'].plot(kind='hist',orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df.hist(figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
df.hist(figsize=(20,10),color='r')
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
df.hist(figsize=(20,10),color='r',alpha = 0.2)
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
#box plot

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot(kind='box',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
#box plot represents quartiles

# %%
#median - middle value after sorting the data

# %%
#Interquartile range (IQR) = distance b/w Q1 and  Q3(25th percentile and 75th percentile)

# %%
#Q1-1.5(IQR) min value

# %%
#Q3 + 1.5(IQR) max value

# %%
#IQR = diff b/w 75th percentile and 25th percentile

# %%
#outlier is  a  dataset which is not able to fit in regular daatset

# %%
df.plot(kind='box',figsize=(20,10),color='r')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box',figsize=(20,10),color={'boxes':'g','whiskers':'r'})
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box',figsize=(20,10),color={'boxes':'g','whiskers':'r'})
# Out:
# <AxesSubplot:>

# %%
#Area Graphh

# %%
df.plot(kind='area',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',figsize=(20,10),alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',figsize=(20,10),alpha=0.4,stacked=False)
# Out:
# <AxesSubplot:>

# %%
#stacked = False = no overlapping/

#stacked = True = one above the another

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#scatter plot

# %%
#relation between two column
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm',c='SepalWidthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
#c is color axis

# %%
#we can se ein above graph color of every dot is not same, range of color is 2 to 5
#based of x and y value it is going to give a color

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm',c='SepalWidthCm',s=600)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
#s mean size

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm',c='SepalWidthCm',s=df['PetalWidthCm']*500)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.hexbin(x='SepalLengthCm',y='PetalLengthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.hexbin(x='SepalLengthCm',y='PetalLengthCm',gridsize=10)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.hexbin(x='SepalLengthCm',y='PetalLengthCm',gridsize=10,C='SepalWidthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
##pie plot

# %%
df.iloc[0]
# Out:
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object

# %%
df1=df.drop(columns='Species').iloc[0]

# %%
df1.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
df.iplot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1430                 try:
# -> 1431                         import chart_studio.plotly as py
#    1432                 except:
#
# ModuleNotFoundError: No module named 'chart_studio'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11104/4163631973.py in <module>
# ----> 1 df.iplot()
#
# ...

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="91d7089b-c98f-42a1-b73c-695707285562" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df=df.drop('Id',axis=1)

# %%
df.iplot() # hovering shows value
# Out:
# <div>                            <div id="93041a52-4655-407e-9f39-939f6bdbbf1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='SepalLengthCm',y='PetalLengthCm',mode='markers')
# Out:
# <div>                            <div id="3b80ed14-ca8b-412e-8194-b578c2b9244a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='SepalLengthCm',y='PetalLengthCm',mode='markers',kind='scatter')
# Out:
# <div>                            <div id="a571d1ca-cf77-4542-8ee8-ea02a84f9d55" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter',mode='markers')
# Out:
# <div>                            <div id="a4ec9ba7-61c6-4af0-9d92-7f018af70858" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter',mode='markers',size=3)
# Out:
# <div>                            <div id="71910227-b3af-4f14-9838-4aa5b8668397" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'bubble',x='SepalLengthCm',y='PetalLengthCm',size='SepalWidthCm')
# Out:
# <div>                            <div id="43caef06-f87c-47aa-9a3e-93db8fb7dec4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="6ec0845f-56a3-4cbe-9d88-1ab28159f1f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#3D

# %%
df.iplot(kind = 'scatter3d' , x = 'SepalLengthCm' , y = 'PetalLengthCm' , z = 'SepalWidthCm')
# Out:
# <div>                            <div id="9a64cbd2-b643-4e55-bebe-85ad4fd24530" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head().iplot(kind = 'scatter3d' , x = 'SepalLengthCm' , y = 'PetalLengthCm' , z = 'SepalWidthCm')
# Out:
# <div>                            <div id="8f058462-4923-4160-8eb8-018f07c53539" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'bubble3d' , x = 'SepalLengthCm' , y = 'PetalLengthCm',z='SepalWidthCm',size='SepalWidthCm' )
# Out:
# <div>                            <div id="6b155908-72a9-41eb-a0d7-bfd7c612055a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
'''homework
try to explore map graph and try to show an example 2-3
'''
